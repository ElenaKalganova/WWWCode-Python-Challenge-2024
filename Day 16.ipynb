# %% [markdown]
# # Day 16

# %% [markdown]
# Write a function that counts the frequency of each word in a sentence.

# %%
def count_words(text):
    """Counts the frequency of each word in a string.

    Parameters
    ----------
    text: str
        The text in which to count words.

    Returns
    -------
    dict
        A dictionary of unique words in the text and their frequency.
    """
    unique_words={}
    all_words=text.lower().split()
    for word in all_words:
        if word in unique_words:
            unique_words[word]+=1
        else:
            unique_words[word]=1
    return(sorted(unique_words.items(), key=lambda x:x[1], reverse=True))

# %%
txt = """About the job
 Welcome to the WWCode Days of Code Challenge 2024! 
Are you ready for a fun coding challenge with a supportive community? The WWCode Days of Code Challenge is an amazing opportunity to practice your coding skills daily in an interactive and supportive community environment. The challenge goal is to code every day for a selected number of days. You will be able to select the level of commitment that works best for you and your schedule while focusing on your chosen tech stack(s). All coding levels are invited.

👩🏽‍💻 Participate
Attend the Opening Ceremony (Stage here on Hopin), or access the recording afterwards, to learn all about how to participate in the program.
Select your commitment level, and determine the tech stack(s) you want to focus on.
Submit the Participant Commitment Form to officially register for the challenge. (Please attend or access the Opening Ceremony before completing this form.)
Join the following Slack channels in the general WWCode Slack community (invitation link):
Join #code-challenge-community to introduce yourself, share your excitement about the challenge, ask questions, and share your progress.
Join #code-challenge to stay completely up-to-date on upcoming announcements, events, and more.
Start coding for the challenge on Monday, January 8, 2024 (or your chosen start date).
Code every day for your selected number of days: 7, 14, 30, 60, or 100.
Share your progress and interact with the amazing community at least once per week. We shared ways to do this during the Opening Ceremony.
Complete the Commitment Completion Form to earn your badge. (Form will be available in mid-January.) 
📆 Key Dates
January 8 - Opening Ceremony & participants start coding
January 14 - 7 days milestone*
January 21 - 14 days milestone*
February 6 - 30 days milestone*
February 9 - Celebration/Closing Ceremony
March 7 - 60 days milestone*
April 16 - 100 days milestone*
* Assumes start date of January 8 with no breaks

📹 Session Recordings
All session recordings are being added to the Days of Code Challenge YouTube playlist as soon as they are available.

Days of Code Challenge 2024 Opening Ceremony YouTube recording - START HERE!
30 Days of JavaScript Coding Challenge Launch YouTube recording | Slack invitation link
Cloud Days of Code Bingo Challenge Launch YouTube recording | Slack invitation link
Machine Learning Challenge Launch YouTube recording | Slack invitation link
Python Days of Code Challenge Launch YouTube recording | Slack invitation link
 

💫 Code of Conduct + Issue Reporting
Women Who Code is dedicated to providing an empowering experience for everyone who participates in or supports our community. Our events are intended to empower diverse women to excel in their technology careers, and anyone there for this purpose is welcome. Because we value the safety and security of our members and strive to have an inclusive community, we do not tolerate harassment of members or event participants in any form. Our Code of Conduct is in place for any Women Who Code event. Any issues? Reach out to global@womenwhocode.com or file an anonymous report at AllVoices.co. Lee el Código de conducta de WWCode en español."""

# %%
count_words(txt)
# Out:
# [('the', 21),
#  ('to', 18),
#  ('of', 15),
#  ('days', 12),
#  ('code', 12),
#  ('challenge', 11),
#  ('your', 10),
#  ('for', 9),
#  ('and', 9),
#  ('in', 8),
#  ('-', 8),
#  ('coding', 6),
#  ('or', 6),
#  ('recording', 6),
#  ('slack', 6),
#  ('youtube', 6),
#  ('are', 5),
#  ('is', 5),
#  ('an', 5),
#  ('opening', 5),
#  ('ceremony', 5),
#  ('start', 5),
#  ('january', 5),
#  ('milestone*', 5),
#  ('wwcode', 4),
#  ('you', 4),
#  ('commitment', 4),
#  ('on', 4),
#  ('launch', 4),
#  ('|', 4),
#  ('invitation', 4),
#  ('link', 4),
#  ('our', 4),
#  ('about', 3),
#  ('a', 3),
#  ('with', 3),
#  ('community', 3),
#  ('all', 3),
#  ('this', 3),
#  ('join', 3),
#  ('share', 3),
#  ('we', 3),
#  ('women', 3),
#  ('who', 3),
#  ('any', 3),
#  ('supportive', 2),
#  ('amazing', 2),
#  ('every', 2),
#  ('day', 2),
#  ('selected', 2),
#  ('number', 2),
#  ('will', 2),
#  ('be', 2),
#  ('select', 2),
#  ('chosen', 2),
#  ('tech', 2),
#  ('participate', 2),
#  ('attend', 2),
# ...
